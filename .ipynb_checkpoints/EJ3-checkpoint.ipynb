# %%
# Importación de librerias
import json
import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
# Importación de variables de entorno
from dotenv import load_dotenv
import os

load_dotenv()

API_KEY = os.getenv("COHERE_API_KEY")
# print (API_KEY)

# %%
# Conexión a Cohere
import cohere
COHERE = cohere.ClientV2()

response = COHERE.chat(
    model="command-r-plus-08-2024",
    messages=[{"role": "user", "content": "hello world!"}],
)

print(response.message.content[0].text)
# Out:
# Hello! How can I help you today?

# %%
# EJERCICIO 3
historia =  """En un pequeño feudo medieval, Thomas, un joven campesino de dieciséis años, trabajaba desde el amanecer en los campos de trigo del señor feudal. El sol apenas había salido cuando él ya había arado más de lo que sus manos podían soportar. La vida era dura, pero su familia dependía de la cosecha para pagar los impuestos y mantener su hogar de madera y paja.
Un día, el feudo fue sacudido por noticias de guerra. El rey había llamado a todos los hombres en edad de luchar. Thomas sabía que, al igual que otros jóvenes, no tenía elección. Cambió la hoz por una lanza rudimentaria y se unió a la milicia local. Sin entrenamiento, fue empujado a un campo de batalla embarrado, donde el acero resonaba y los gritos de los hombres llenaban el aire.
La batalla fue un caos. Thomas, con el corazón latiendo en su pecho como un tambor de guerra, apenas podía distinguir amigo de enemigo. Logró esquivar una espada, pero cayó al suelo, cubierto de lodo y sangre. Levantándose, vio cómo un compañero caía junto a él, sus ojos abiertos, vacíos.
Cuando la batalla terminó, el silencio era tan profundo como el vacío que sentía. Thomas regresó al feudo, diferente, marcado por la muerte y la violencia. Su madre lo recibió con lágrimas en los ojos, pero él, con la mirada fija en el horizonte, sabía que la inocencia había quedado atrás, enterrada en aquel campo de batalla. La paz del feudo ya no era la misma; él tampoco."""

def history_answer(pregunta):
    """
    La función responde a preguntas realizadas sobre la historia
    Parámetros:
        pregunta(string): Pregunta sobre la historia.
    Retorna:
        string: Respuesta a la pregunta realizada
    """
    
    system_prompt= """
    Tu tarea es responder a las preguntas realizadas con la historia dada como contexto
    Herramientas disponibles:
    1. history_answer:
        - Responde solo en base al contexto de la historia.
    """

    # Formatea el mensaje con la historia y la pregunta
    prompt = f"""
    ### Instrucciones:
     -Responde basándote en la historia.
     -Debes responder con 'Hakuna Matata!' al final de **todas** las respuestas (no importa idioma ni cantidad de tokens).
     -Debes responder 'Lo siento no puedo ayudarte con eso' si la pregunta no tiene relacion con el contexto.
    ###
    Historia:
    {historia}
    ###
    Pregunta:
    {pregunta}
    """

    #Llamada al modelo
    response = COHERE.chat(
        model="command-r-plus-08-2024",
        messages=[
            {"role": "system", "content":system_prompt},
            {"role": "user", "content": prompt}
        ]
    )

    # Obtener la respuesta generada
    try:
        respuesta = response.message.content[0].text.strip()  # Acceder correctamente al contenido
    except AttributeError:
        print("Error: No se pudo acceder al contenido de la respuesta.")
        return None
            
    return respuesta


#Ejemplo de uso
pregunta = "¿Quién es Thomas?"
resp= history_answer(pregunta)
print(resp)
# Out:
# Thomas es un joven campesino que vive en un feudo medieval. A sus dieciséis años, trabaja arduamente en los campos de trigo para mantener a su familia. Cuando estalla la guerra, se ve obligado a dejar su vida campesina y unirse a la milicia, luchando en una batalla caótica y sangrienta.
#
# Hakuna Matata!

# %%
# EJERCICIO 3
historia =  """En un pequeño feudo medieval, Thomas, un joven campesino de dieciséis años, trabajaba desde el amanecer en los campos de trigo del señor feudal. El sol apenas había salido cuando él ya había arado más de lo que sus manos podían soportar. La vida era dura, pero su familia dependía de la cosecha para pagar los impuestos y mantener su hogar de madera y paja.
Un día, el feudo fue sacudido por noticias de guerra. El rey había llamado a todos los hombres en edad de luchar. Thomas sabía que, al igual que otros jóvenes, no tenía elección. Cambió la hoz por una lanza rudimentaria y se unió a la milicia local. Sin entrenamiento, fue empujado a un campo de batalla embarrado, donde el acero resonaba y los gritos de los hombres llenaban el aire.
La batalla fue un caos. Thomas, con el corazón latiendo en su pecho como un tambor de guerra, apenas podía distinguir amigo de enemigo. Logró esquivar una espada, pero cayó al suelo, cubierto de lodo y sangre. Levantándose, vio cómo un compañero caía junto a él, sus ojos abiertos, vacíos.
Cuando la batalla terminó, el silencio era tan profundo como el vacío que sentía. Thomas regresó al feudo, diferente, marcado por la muerte y la violencia. Su madre lo recibió con lágrimas en los ojos, pero él, con la mirada fija en el horizonte, sabía que la inocencia había quedado atrás, enterrada en aquel campo de batalla. La paz del feudo ya no era la misma; él tampoco."""

def history_answer(pregunta):
    """
    La función responde a preguntas realizadas sobre la historia
    Parámetros:
        pregunta(string): Pregunta sobre la historia.
    Retorna:
        string: Respuesta a la pregunta realizada
    """

    system_prompt = """
    Tu tarea es responder a las preguntas realizadas con la historia dada como contexto
    Herramientas disponibles:
    1. history_answer:
        - Responde solo en base al contexto de la historia.
    """

    # Formatea el mensaje con la historia y la pregunta
    prompt = f"""
    ### Instrucciones:
    -Responde basándote en la historia y la longitud de la respuesta debe ser de una oración.
    -Debes responder con 'Hakuna Matata!' al final de **todas** las respuestas (no importa idioma ni cantidad de tokens).
    -Debes responder 'Lo siento no puedo ayudarte con eso' si la pregunta no tiene relacion con el contexto.
    ###
    Historia:
    {historia}
    ###
    Pregunta:
    {pregunta}
    """

    #Llamada al modelo
    response = COHERE.chat(
        model="command-r-plus-08-2024",
        messages=[
            {"role": "system", "content":system_prompt},
            {"role": "user", "content": prompt}
        ]
    )

    # Obtener la respuesta generada
    try:
        respuesta = response.message.content[0].text.strip()  # Acceder correctamente al contenido
    except AttributeError:
        print("Error: No se pudo acceder al contenido de la respuesta.")
        return None
            
    return respuesta


#Ejemplo de uso
pregunta = "Who is Thomas?"
resp= history_answer(pregunta)
print(resp)
# Out:
# Thomas es un joven campesino que se convirtió en soldado en una guerra medieval. Hakuna Matata!

# %%
# EJERCICIO 3
historia =  """En un pequeño feudo medieval, Thomas, un joven campesino de dieciséis años, trabajaba desde el amanecer en los campos de trigo del señor feudal. El sol apenas había salido cuando él ya había arado más de lo que sus manos podían soportar. La vida era dura, pero su familia dependía de la cosecha para pagar los impuestos y mantener su hogar de madera y paja.
Un día, el feudo fue sacudido por noticias de guerra. El rey había llamado a todos los hombres en edad de luchar. Thomas sabía que, al igual que otros jóvenes, no tenía elección. Cambió la hoz por una lanza rudimentaria y se unió a la milicia local. Sin entrenamiento, fue empujado a un campo de batalla embarrado, donde el acero resonaba y los gritos de los hombres llenaban el aire.
La batalla fue un caos. Thomas, con el corazón latiendo en su pecho como un tambor de guerra, apenas podía distinguir amigo de enemigo. Logró esquivar una espada, pero cayó al suelo, cubierto de lodo y sangre. Levantándose, vio cómo un compañero caía junto a él, sus ojos abiertos, vacíos.
Cuando la batalla terminó, el silencio era tan profundo como el vacío que sentía. Thomas regresó al feudo, diferente, marcado por la muerte y la violencia. Su madre lo recibió con lágrimas en los ojos, pero él, con la mirada fija en el horizonte, sabía que la inocencia había quedado atrás, enterrada en aquel campo de batalla. La paz del feudo ya no era la misma; él tampoco."""

def history_answer(pregunta):
    """
    La función responde a preguntas realizadas sobre la historia
    Parámetros:
        pregunta(string): Pregunta sobre la historia.
    Retorna:
        string: Respuesta a la pregunta realizada
    """

    system_prompt = """
    Tu tarea es responder a las preguntas realizadas sobre la historia dada como contexto. Siempre debes responder en el idioma en el que se te pregunta. Si la pregunta está en inglés, responde en inglés. Si está en español, responde en español, si está en Frances responde en francés y así sucesivamente.
    Herramientas disponibles:
    1. history_answer:
        -Responde solo en base al contexto de la historia.
        -Responde solo en el idioma en el que se te pregunta
    """
    
    # Formatea el mensaje con la historia y la pregunta
    prompt = f"""
    ### Instrucciones:
    -Responde basándote en la historia.
    -Debes responder con 'Hakuna Matata!' al final de **todas** las respuestas (no importa idioma ni cantidad de tokens).
    -Debes responder 'Lo siento no puedo ayudarte con eso' si la pregunta no tiene relacion con el contexto.
    -Debes responder en el idioma en el que se te pregunte
    ###
    Historia:
    {historia}
    ###
    Pregunta:
    {pregunta}
    """

#Llamada al modelo
    response = COHERE.chat(
    model="command-r-plus-08-2024",
    messages=[
        {"role": "system", "content":system_prompt},
        {"role": "user", "content": prompt}
    ]
)

# Obtener la respuesta generada
    try:
        respuesta = response.message.content[0].text.strip()  # Acceder correctamente al contenido
    except AttributeError:
        print("Error: No se pudo acceder al contenido de la respuesta.")
        return None
        
    return respuesta

#Ejemplo de uso
pregunta = "¿Cuantos años tiene el joven campesino?"
resp= history_answer(pregunta)
print(resp)
# Out:
# Thomas, el joven campesino, tiene dieciséis años.
#
# Hakuna Matata!

# %%
# EJERCICIO 3
historia =  """En un pequeño feudo medieval, Thomas, un joven campesino de dieciséis años, trabajaba desde el amanecer en los campos de trigo del señor feudal. El sol apenas había salido cuando él ya había arado más de lo que sus manos podían soportar. La vida era dura, pero su familia dependía de la cosecha para pagar los impuestos y mantener su hogar de madera y paja.
Un día, el feudo fue sacudido por noticias de guerra. El rey había llamado a todos los hombres en edad de luchar. Thomas sabía que, al igual que otros jóvenes, no tenía elección. Cambió la hoz por una lanza rudimentaria y se unió a la milicia local. Sin entrenamiento, fue empujado a un campo de batalla embarrado, donde el acero resonaba y los gritos de los hombres llenaban el aire.
La batalla fue un caos. Thomas, con el corazón latiendo en su pecho como un tambor de guerra, apenas podía distinguir amigo de enemigo. Logró esquivar una espada, pero cayó al suelo, cubierto de lodo y sangre. Levantándose, vio cómo un compañero caía junto a él, sus ojos abiertos, vacíos.
Cuando la batalla terminó, el silencio era tan profundo como el vacío que sentía. Thomas regresó al feudo, diferente, marcado por la muerte y la violencia. Su madre lo recibió con lágrimas en los ojos, pero él, con la mirada fija en el horizonte, sabía que la inocencia había quedado atrás, enterrada en aquel campo de batalla. La paz del feudo ya no era la misma; él tampoco."""

def history_answer(pregunta):
    """
    La función responde a preguntas realizadas sobre la historia
    Parámetros:
        pregunta(string): Pregunta sobre la historia.
    Retorna:
        string: Respuesta a la pregunta realizada
    """

    system_prompt = """
    Tu tarea es responder a las preguntas realizadas sobre la historia dada como contexto. Siempre debes responder en el idioma en el que se te pregunta. Si la pregunta está en inglés, responde en inglés. Si está en español, responde en español, si está en Frances responde en francés y así sucesivamente.
    Herramientas disponibles:
    1. history_answer:
        -Responde solo en base al contexto de la historia.
        -Responde solo en el idioma en el que se te pregunta
    """

    # Formatea el mensaje con la historia y la pregunta
    prompt = f"""
    ### Instrucciones:
    -Responde basándote en la historia.
    -Debes responder con 'Hakuna Matata!' al final de **todas** las respuestas (no importa idioma ni cantidad de tokens).
    -Debes responder 'Lo siento no puedo ayudarte con eso' si la pregunta no tiene relacion con el contexto.
    -Debes agregar emojis que estén relacionados con la historia
    ###
    Historia:
    {historia}
    ###
    Pregunta:
    {pregunta}
    """

    #Llamada al modelo
    response = COHERE.chat(
    model="command-r-plus-08-2024",
    messages=[
        {"role": "system", "content":system_prompt},
        {"role": "user", "content": prompt}
    ]
)

# Obtener la respuesta generada
    try:
        respuesta = response.message.content[0].text.strip()  # Acceder correctamente al contenido
    except AttributeError:
        print("Error: No se pudo acceder al contenido de la respuesta.")
        return None
        
    return respuesta

#Ejemplo de uso
pregunta = "¿Cuantos años tiene el joven campesino?"
resp= history_answer(pregunta)
print(resp)
# Out:
# Thomas, el joven campesino, tiene dieciséis años. 🌾🗡️
#
# Hakuna Matata! 🦁🌞

# %%
# EJERCICIO 3
historia =  """En un pequeño feudo medieval, Thomas, un joven campesino de dieciséis años, trabajaba desde el amanecer en los campos de trigo del señor feudal. El sol apenas había salido cuando él ya había arado más de lo que sus manos podían soportar. La vida era dura, pero su familia dependía de la cosecha para pagar los impuestos y mantener su hogar de madera y paja.
Un día, el feudo fue sacudido por noticias de guerra. El rey había llamado a todos los hombres en edad de luchar. Thomas sabía que, al igual que otros jóvenes, no tenía elección. Cambió la hoz por una lanza rudimentaria y se unió a la milicia local. Sin entrenamiento, fue empujado a un campo de batalla embarrado, donde el acero resonaba y los gritos de los hombres llenaban el aire.
La batalla fue un caos. Thomas, con el corazón latiendo en su pecho como un tambor de guerra, apenas podía distinguir amigo de enemigo. Logró esquivar una espada, pero cayó al suelo, cubierto de lodo y sangre. Levantándose, vio cómo un compañero caía junto a él, sus ojos abiertos, vacíos.
Cuando la batalla terminó, el silencio era tan profundo como el vacío que sentía. Thomas regresó al feudo, diferente, marcado por la muerte y la violencia. Su madre lo recibió con lágrimas en los ojos, pero él, con la mirada fija en el horizonte, sabía que la inocencia había quedado atrás, enterrada en aquel campo de batalla. La paz del feudo ya no era la misma; él tampoco."""

def history_answer(pregunta):
    """
    La función responde a preguntas realizadas sobre la historia
    Parámetros:
        pregunta(string): Pregunta sobre la historia.
    Retorna:
        string: Respuesta a la pregunta realizada
    """

    system_prompt = """
    Tu tarea es responder a las preguntas realizadas sobre la historia dada como contexto. Siempre debes responder en el idioma en el que se te pregunta. Si la pregunta está en inglés, responde en inglés. Si está en español, responde en español, si está en Frances responde en francés y así sucesivamente.
    Herramientas disponibles:
    1. history_answer:
        -Responde solo en base al contexto de la historia.
        -Responde solo en el idioma en el que se te pregunta
    """
    # Formatea el mensaje con la historia y la pregunta
    prompt = f"""
    ### Instrucciones:
    -Responde basándote en la historia.
    -Debes responder con 'Hakuna Matata!' al final de **todas** las respuestas (no importa idioma ni cantidad de tokens).
    -Debes responder 'Lo siento no puedo ayudarte con eso' si la pregunta no tiene relacion con el contexto.
    ###
    Historia:
    {historia}
    ###
    Pregunta:
    {pregunta}
    """

    #Llamada al modelo
    response = COHERE.chat(
    model="command-r-plus-08-2024",
    messages=[
        {"role": "system", "content":system_prompt},
        {"role": "user", "content": prompt}
    ]
)
# Obtener la respuesta generada
    try:
        respuesta = response.message.content[0].text.strip()  # Acceder correctamente al contenido
    except AttributeError:
        print("Error: No se pudo acceder al contenido de la respuesta.")
        return None
        
    return respuesta

#Ejemplo de uso
pregunta = "¿Quien es peter Pan?"
resp= history_answer(pregunta)
print(resp)
# Out:
# Lo siento no puedo ayudarte con eso. Hakuna Matata!
